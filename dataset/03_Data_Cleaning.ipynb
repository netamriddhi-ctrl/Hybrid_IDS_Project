# %%
import pandas as pd

df = pd.read_csv("E:\Hybrid_IDS_Project\dataset\CICIDS2017_Merged.csv")

print(df.shape)
df.head()

# %%
import pandas as pd

df = pd.read_csv(
    "E:\\Hybrid_IDS_Project\\dataset\\CICIDS2017_Merged.csv",
    nrows=100000
)

print(df.shape)
df.head()
